# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LogisticRegression
import statsmodels.api as sm
from functools import reduce
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set(style="white", palette="muted", color_codes=True)
import os

# %%
filenames = ['NHANES-Downloader/data/raw_data/2005-2006/Demographics/DEMO_D.XPT',
             'NHANES-Downloader/data/raw_data/2007-2008/Demographics/DEMO_E.XPT',
             'NHANES-Downloader/data/raw_data/2009-2010/Demographics/DEMO_F.XPT',
             'NHANES-Downloader/data/raw_data/2011-2012/Demographics/DEMO_G.XPT',
             'NHANES-Downloader/data/raw_data/2013-2014/Demographics/DEMO_H.XPT',
             'NHANES-Downloader/data/raw_data/2015-2016/Demographics/DEMO_I.XPT']
  
demo_df = [] 
for filename in filenames: 
    demo_df.append(pd.read_sas(filename))

# %%
demo_df[0] = demo_df[0].rename(columns={'INDFMINC': 'INDFMIN2'})
demo_df = pd.concat(demo_df, ignore_index=True)

# %%
demo_list = ['SEQN', 'RIAGENDR', 'RIDAGEYR', 'RIDRETH1', 'INDFMIN2']
demo = demo_df.loc[:, demo_list]

# %%
filenames = ['NHANES-Downloader/data/raw_data/2005-2006/Examination/BPX_D.XPT',
             'NHANES-Downloader/data/raw_data/2007-2008/Examination/BPX_E.XPT',
             'NHANES-Downloader/data/raw_data/2009-2010/Examination/BPX_F.XPT',
             'NHANES-Downloader/data/raw_data/2011-2012/Examination/BPX_G.XPT',
             'NHANES-Downloader/data/raw_data/2013-2014/Examination/BPX_H.XPT',
             'NHANES-Downloader/data/raw_data/2015-2016/Examination/BPX_I.XPT']
  
bpx_df = [] 
for filename in filenames: 
    bpx_df.append(pd.read_sas(filename))

# %%
bpx_df = pd.concat(bpx_df, ignore_index=True)
bpx_list = ['SEQN', 'BPXPULS','BPXSY1', 'BPXDI1']
bpx = bpx_df.loc[:, bpx_list]

# %%
filenames = ['NHANES-Downloader/data/raw_data/2005-2006/Examination/BMX_D.XPT',
             'NHANES-Downloader/data/raw_data/2007-2008/Examination/BMX_E.XPT',
             'NHANES-Downloader/data/raw_data/2009-2010/Examination/BMX_F.XPT',
             'NHANES-Downloader/data/raw_data/2011-2012/Examination/BMX_G.XPT',
             'NHANES-Downloader/data/raw_data/2013-2014/Examination/BMX_H.XPT',
             'NHANES-Downloader/data/raw_data/2015-2016/Examination/BMX_I.XPT']

  
bmx_df = [] 
for filename in filenames: 
    bmx_df.append(pd.read_sas(filename))

# %%
bmx_df = pd.concat(bmx_df, ignore_index=True)
bmx_list = ['SEQN', 'BMXBMI', 'BMXWAIST']
bmx = bmx_df.loc[:, bmx_list]

# %%
filenames = ['NHANES-Downloader/data/raw_data/2005-2006/Laboratory/HDL_D.XPT',
             'NHANES-Downloader/data/raw_data/2007-2008/Laboratory/HDL_E.XPT',
             'NHANES-Downloader/data/raw_data/2009-2010/Laboratory/HDL_F.XPT',
             'NHANES-Downloader/data/raw_data/2011-2012/Laboratory/HDL_G.XPT',
             'NHANES-Downloader/data/raw_data/2013-2014/Laboratory/HDL_H.XPT',
             'NHANES-Downloader/data/raw_data/2015-2016/Laboratory/HDL_I.XPT']

hdl_df = [] 
for filename in filenames: 
    hdl_df.append(pd.read_sas(filename))

# %%
hdl_df = pd.concat(hdl_df, ignore_index=True)
hdl_list = ['SEQN', 'LBDHDD']
hdl = hdl_df.loc[:, hdl_list]

# %%
filenames = ['NHANES-Downloader/data/raw_data/2005-2006/Laboratory/TRIGLY_D.XPT',
             'NHANES-Downloader/data/raw_data/2007-2008/Laboratory/TRIGLY_E.XPT',
             'NHANES-Downloader/data/raw_data/2009-2010/Laboratory/TRIGLY_F.XPT',
             'NHANES-Downloader/data/raw_data/2011-2012/Laboratory/TRIGLY_G.XPT',
             'NHANES-Downloader/data/raw_data/2013-2014/Laboratory/TRIGLY_H.XPT',
             'NHANES-Downloader/data/raw_data/2015-2016/Laboratory/TRIGLY_I.XPT']

trigly_df = [] 
for filename in filenames: 
    trigly_df.append(pd.read_sas(filename))

# %%
trigly_df = pd.concat(trigly_df, ignore_index=True)
trigly_list = ['SEQN', 'LBXTR', 'LBDLDL']
trigly = trigly_df.loc[:, trigly_list]

# %%
filenames = ['NHANES-Downloader/data/raw_data/2005-2006/Laboratory/TCHOL_D.XPT',
             'NHANES-Downloader/data/raw_data/2007-2008/Laboratory/TCHOL_E.XPT',
             'NHANES-Downloader/data/raw_data/2009-2010/Laboratory/TCHOL_F.XPT',
             'NHANES-Downloader/data/raw_data/2011-2012/Laboratory/TCHOL_G.XPT',
             'NHANES-Downloader/data/raw_data/2013-2014/Laboratory/TCHOL_H.XPT',
             'NHANES-Downloader/data/raw_data/2015-2016/Laboratory/TCHOL_I.XPT']

tchol_df = [] 
for filename in filenames: 
    tchol_df.append(pd.read_sas(filename))

# %%
tchol_df = pd.concat(tchol_df, ignore_index=True)
tchol_list = ['SEQN', 'LBXTC']
tchol = tchol_df.loc[:, tchol_list]

# %%
filenames = ['NHANES-Downloader/data/raw_data/2005-2006/Questionnaire/DIQ_D.XPT',
             'NHANES-Downloader/data/raw_data/2007-2008/Questionnaire/DIQ_E.XPT',
             'NHANES-Downloader/data/raw_data/2009-2010/Questionnaire/DIQ_F.XPT',
             'NHANES-Downloader/data/raw_data/2011-2012/Questionnaire/DIQ_G.XPT',
             'NHANES-Downloader/data/raw_data/2013-2014/Questionnaire/DIQ_H.XPT',
             'NHANES-Downloader/data/raw_data/2015-2016/Questionnaire/DIQ_I.XPT']

diab_df = [] 
for filename in filenames: 
    diab_df.append(pd.read_sas(filename))

# %%
diab_df = pd.concat(diab_df, ignore_index=True)
diab_list = ['SEQN', 'DIQ010']
diab = diab_df.loc[:, diab_list]

# %%
filenames = ['NHANES-Downloader/data/raw_data/2005-2006/Questionnaire/KIQ_U_D.XPT',
             'NHANES-Downloader/data/raw_data/2007-2008/Questionnaire/KIQ_U_E.XPT',
             'NHANES-Downloader/data/raw_data/2009-2010/Questionnaire/KIQ_U_F.XPT',
             'NHANES-Downloader/data/raw_data/2011-2012/Questionnaire/KIQ_U_G.XPT',
             'NHANES-Downloader/data/raw_data/2013-2014/Questionnaire/KIQ_U_H.XPT',
             'NHANES-Downloader/data/raw_data/2015-2016/Questionnaire/KIQ_U_I.XPT']

kidney_df = [] 
for filename in filenames: 
    kidney_df.append(pd.read_sas(filename))

# %%
kidney_df = pd.concat(kidney_df, ignore_index=True)
kidney_list = ['SEQN', 'KIQ022']
kidney = kidney_df.loc[:, kidney_list]

# %%
filenames = ['NHANES-Downloader/data/raw_data/2005-2006/Questionnaire/MCQ_D.XPT',
             'NHANES-Downloader/data/raw_data/2007-2008/Questionnaire/MCQ_E.XPT',
             'NHANES-Downloader/data/raw_data/2009-2010/Questionnaire/MCQ_F.XPT',
             'NHANES-Downloader/data/raw_data/2011-2012/Questionnaire/MCQ_G.XPT',
             'NHANES-Downloader/data/raw_data/2013-2014/Questionnaire/MCQ_H.XPT',
             'NHANES-Downloader/data/raw_data/2015-2016/Questionnaire/MCQ_I.XPT']

heart_df = [] 
for filename in filenames: 
    heart_df.append(pd.read_sas(filename))

# %%
heart_df = pd.concat(heart_df, ignore_index=True)
heart_list = ['SEQN', 'MCQ160B', 'MCQ160C', 'MCQ160D', 'MCQ160E', 'MCQ160F', 'MCQ300A']
heart = heart_df.loc[:, heart_list]

# %%
filenames = ['NHANES-Downloader/data/raw_data/2005-2006/Questionnaire/SMQ_D.XPT',
             'NHANES-Downloader/data/raw_data/2007-2008/Questionnaire/SMQ_E.XPT',
             'NHANES-Downloader/data/raw_data/2009-2010/Questionnaire/SMQ_F.XPT',
             'NHANES-Downloader/data/raw_data/2011-2012/Questionnaire/SMQ_G.XPT',
             'NHANES-Downloader/data/raw_data/2013-2014/Questionnaire/SMQ_H.XPT',
             'NHANES-Downloader/data/raw_data/2015-2016/Questionnaire/SMQ_I.XPT']

smoking_df = [] 
for filename in filenames: 
    smoking_df.append(pd.read_sas(filename))

# %%
smoking_df = pd.concat(smoking_df, ignore_index=True)
smoking_list = ['SEQN', 'SMQ020']
smoking = smoking_df.loc[:, smoking_list]

# %%
pdList = [demo, bpx, bmx, hdl, trigly, tchol, diab,
          kidney, heart, smoking]
df = reduce(lambda x,y: pd.merge(x,y, on='SEQN', how='outer'), pdList)

# %%
df.head()
# Out:
#       SEQN  RIAGENDR      RIDAGEYR  RIDRETH1  INDFMIN2  BPXPULS  BPXSY1  \
# 0  31127.0       1.0  5.397605e-79       3.0       4.0      1.0     NaN
# 1  31128.0       2.0  1.100000e+01       4.0       5.0      1.0   100.0
# 2  31129.0       1.0  1.500000e+01       4.0      10.0      1.0   104.0
# 3  31130.0       2.0  8.500000e+01       3.0       4.0      1.0     NaN
# 4  31131.0       2.0  4.400000e+01       4.0      11.0      1.0   144.0
#
#    BPXDI1  BMXBMI  BMXWAIST  ...  LBXTC  DIQ010  KIQ022  MCQ160B  MCQ160C  \
# 0     NaN     NaN       NaN  ...    NaN     NaN     NaN      NaN      NaN
# 1    62.0   17.45      62.8  ...  129.0     2.0     NaN      NaN      NaN
# 2    76.0   26.53      97.8  ...  170.0     2.0     NaN      NaN      NaN
# 3     NaN     NaN       NaN  ...    NaN     2.0     2.0      2.0      2.0
# 4    74.0   30.90      96.0  ...  105.0     2.0     2.0      1.0      2.0
#
#    MCQ160D  MCQ160E  MCQ160F  MCQ300A  SMQ020
# 0      NaN      NaN      NaN      NaN     NaN
# 1      NaN      NaN      NaN      NaN     NaN
# 2      NaN      NaN      NaN      NaN     NaN
# 3      2.0      2.0      2.0      2.0     2.0
# 4      2.0      2.0      2.0      1.0     2.0
#
# [5 rows x 23 columns]

# %%
df.shape
# Out:
# (60936, 23)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 60936 entries, 0 to 60935
# Data columns (total 23 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   SEQN      60936 non-null  float64
#  1   RIAGENDR  60936 non-null  float64
#  2   RIDAGEYR  60936 non-null  float64
#  3   RIDRETH1  60936 non-null  float64
#  4   INDFMIN2  60157 non-null  float64
#  5   BPXPULS   56567 non-null  float64
#  6   BPXSY1    42417 non-null  float64
#  7   BPXDI1    42417 non-null  float64
#  8   BMXBMI    53635 non-null  float64
#  9   BMXWAIST  51361 non-null  float64
#  10  LBDHDD    44462 non-null  float64
#  11  LBXTR     18404 non-null  float64
#  12  LBDLDL    18115 non-null  float64
#  13  LBXTC     44461 non-null  float64
#  14  DIQ010    58304 non-null  float64
#  15  KIQ022    34179 non-null  float64
#  16  MCQ160B   34179 non-null  float64
#  17  MCQ160C   34179 non-null  float64
#  18  MCQ160D   34179 non-null  float64
#  19  MCQ160E   34179 non-null  float64
#  20  MCQ160F   34179 non-null  float64
#  21  MCQ300A   34179 non-null  float64
#  22  SMQ020    34796 non-null  float64
# dtypes: float64(23)
# memory usage: 11.2 MB

# %%
df = df[df.RIDAGEYR >=20]
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 34180 entries, 3 to 60935
# Data columns (total 23 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   SEQN      34180 non-null  float64
#  1   RIAGENDR  34180 non-null  float64
#  2   RIDAGEYR  34180 non-null  float64
#  3   RIDRETH1  34180 non-null  float64
#  4   INDFMIN2  33726 non-null  float64
#  5   BPXPULS   31636 non-null  float64
#  6   BPXSY1    30128 non-null  float64
#  7   BPXDI1    30128 non-null  float64
#  8   BMXBMI    32444 non-null  float64
#  9   BMXWAIST  30952 non-null  float64
#  10  LBDHDD    30921 non-null  float64
#  11  LBXTR     14769 non-null  float64
#  12  LBDLDL    14489 non-null  float64
#  13  LBXTC     30921 non-null  float64
#  14  DIQ010    34180 non-null  float64
#  15  KIQ022    34179 non-null  float64
#  16  MCQ160B   34179 non-null  float64
#  17  MCQ160C   34179 non-null  float64
#  18  MCQ160D   34179 non-null  float64
#  19  MCQ160E   34179 non-null  float64
#  20  MCQ160F   34179 non-null  float64
#  21  MCQ300A   34179 non-null  float64
#  22  SMQ020    34179 non-null  float64
# dtypes: float64(23)
# memory usage: 6.3 MB

# %%
df.shape
# Out:
# (34180, 23)

# %%
missing = pd.concat([df.isnull().sum(), 100*df.isnull().mean()], axis=1)
missing.columns = ['count', 'percentage']
missing.sort_values(by='count', ascending=False)
# Out:
#           count  percentage
# LBDLDL    19691   57.609713
# LBXTR     19411   56.790521
# BPXSY1     4052   11.854886
# BPXDI1     4052   11.854886
# LBDHDD     3259    9.534816
# LBXTC      3259    9.534816
# BMXWAIST   3228    9.444119
# BPXPULS    2544    7.442949
# BMXBMI     1736    5.078994
# INDFMIN2    454    1.328262
# MCQ160B       1    0.002926
# MCQ300A       1    0.002926
# MCQ160F       1    0.002926
# MCQ160E       1    0.002926
# MCQ160D       1    0.002926
# MCQ160C       1    0.002926
# SMQ020        1    0.002926
# KIQ022        1    0.002926
# DIQ010        0    0.000000
# RIAGENDR      0    0.000000
# RIDRETH1      0    0.000000
# RIDAGEYR      0    0.000000
# SEQN          0    0.000000

# %%
import missingno as mno
mno.matrix(df, figsize = (20, 6))

# %%
df=df[df['LBDLDL'].notna()].reset_index(drop=True)

# %%
missing = pd.concat([df.isnull().sum(), 100*df.isnull().mean()], axis=1)
missing.columns = ['count', 'percentage']
missing.sort_values(by='count', ascending=False)
# Out:
#           count  percentage
# BPXSY1     1152    7.950859
# BPXDI1     1152    7.950859
# BMXWAIST    595    4.106564
# BPXPULS     489    3.374974
# BMXBMI      177    1.221616
# INDFMIN2    156    1.076679
# SEQN          0    0.000000
# KIQ022        0    0.000000
# MCQ300A       0    0.000000
# MCQ160F       0    0.000000
# MCQ160E       0    0.000000
# MCQ160D       0    0.000000
# MCQ160C       0    0.000000
# MCQ160B       0    0.000000
# LBXTR         0    0.000000
# DIQ010        0    0.000000
# LBXTC         0    0.000000
# LBDLDL        0    0.000000
# RIAGENDR      0    0.000000
# LBDHDD        0    0.000000
# RIDRETH1      0    0.000000
# RIDAGEYR      0    0.000000
# SMQ020        0    0.000000

# %%
df.shape
# Out:
# (14489, 23)

# %%
df[['BPXSY1', 'BPXDI1', 'BMXBMI', 'BMXWAIST']] = df[['BPXSY1', 'BPXDI1', 'BMXBMI',
                                                     'BMXWAIST']].fillna(df[['BPXSY1','BPXDI1', 'BMXBMI', 'BMXWAIST']].mean())

# %%
df.replace({'BPXPULS': {np.nan: 1}}, inplace=True)

# %%
df['INDFMIN2'].fillna(df['INDFMIN2'].mode()[0], inplace=True)

# %% [markdown]
# columns = ['BPXSY1', 'BPXDI1', 'BMXWAIST', 'BPXPULS', 'BMXBMI', 'INDFMIN2']
# for col in columns:
#     df[col].fillna(df[col].value_counts().idxmax(), inplace=True)

# %%
df.shape
# Out:
# (14489, 23)

# %%
df.dtypes
# Out:
# SEQN        float64
# RIAGENDR    float64
# RIDAGEYR    float64
# RIDRETH1    float64
# INDFMIN2    float64
# BPXPULS     float64
# BPXSY1      float64
# BPXDI1      float64
# BMXBMI      float64
# BMXWAIST    float64
# LBDHDD      float64
# LBXTR       float64
# LBDLDL      float64
# LBXTC       float64
# DIQ010      float64
# KIQ022      float64
# MCQ160B     float64
# MCQ160C     float64
# MCQ160D     float64
# MCQ160E     float64
# MCQ160F     float64
# MCQ300A     float64
# SMQ020      float64
# dtype: object

# %%
df.columns
# Out:
# Index(['SEQN', 'RIAGENDR', 'RIDAGEYR', 'RIDRETH1', 'INDFMIN2', 'BPXPULS',
#        'BPXSY1', 'BPXDI1', 'BMXBMI', 'BMXWAIST', 'LBDHDD', 'LBXTR', 'LBDLDL',
#        'LBXTC', 'DIQ010', 'KIQ022', 'MCQ160B', 'MCQ160C', 'MCQ160D', 'MCQ160E',
#        'MCQ160F', 'MCQ300A', 'SMQ020'],
#       dtype='object')

# %%
dtype_cols = [col for col in df.columns if col not in ['BMXBMI', 'BMXWAIST']]

for col in dtype_cols:
    df[col] = df[col].astype('int')

# %%
df.dtypes
# Out:
# SEQN          int64
# RIAGENDR      int64
# RIDAGEYR      int64
# RIDRETH1      int64
# INDFMIN2      int64
# BPXPULS       int64
# BPXSY1        int64
# BPXDI1        int64
# BMXBMI      float64
# BMXWAIST    float64
# LBDHDD        int64
# LBXTR         int64
# LBDLDL        int64
# LBXTC         int64
# DIQ010        int64
# KIQ022        int64
# MCQ160B       int64
# MCQ160C       int64
# MCQ160D       int64
# MCQ160E       int64
# MCQ160F       int64
# MCQ300A       int64
# SMQ020        int64
# dtype: object

# %%
df.rename(columns={'SEQN': 'seqn', 'RIAGENDR': 'gender', 'RIDAGEYR':'age',
                   'RIDRETH1':'ethnicity', 'INDFMIN2':'income', 'BPXPULS':'pulse_regular',
                   'BPXSY1':'sysbp', 'BPXDI1':'diabp', 'BMXBMI':'bmi',
                   'BMXWAIST':'waistcircum', 'LBDHDD':'hdl', 'LBXTR':'trigly',
                   'LBDLDL':'ldl', 'LBXTC':'totchol', 'DIQ010':'diabetes',
                   'KIQ022':'kidney_fail', 'MCQ160B':'congestive_fail', 'MCQ160C':'coronary_disease',
                   'MCQ160D':'angina', 'MCQ160E':'heart_attack',
                   'MCQ160F':'stroke', 'MCQ300A':'fam_history', 'SMQ020':'smoking'}, inplace=True)
df.set_index('seqn', inplace=True)

# %%
df.head()
# Out:
#        gender  age  ethnicity  income  pulse_regular  sysbp  diabp    bmi  \
# seqn
# 31131       2   44          4      11              1    144     74  30.90
# 31132       1   70          3      11              1    138     60  24.74
# 31134       1   73          3      12              1    130     68  30.63
# 31150       1   79          3       3              1    144     74  28.93
# 31151       2   59          4       7              1    136     76  29.51
#
#        waistcircum  hdl  ...  totchol  diabetes  kidney_fail  congestive_fail  \
# seqn                     ...
# 31131         96.0   39  ...      105         2            2                1
# 31132         96.5   59  ...      147         1            2                2
# 31134        117.1   49  ...      186         2            2                2
# 31150        107.7   81  ...      181         2            2                2
# 31151        101.2   76  ...      205         1            1                2
#
#        coronary_disease  angina  heart_attack  stroke  fam_history  smoking
# seqn
# 31131                 2       2             2       2            1        2
# 31132                 2       2             2       2            2        2
# 31134                 2       2             2       2            2        2
# 31150                 2       2             2       2            2        1
# 31151                 2       2             2       1            1        1
#
# [5 rows x 22 columns]

# %%
df.hist(figsize=(15, 10))
plt.subplots_adjust(hspace=0.5)
plt.show()

# %%
df['ethnicity'].value_counts(normalize=True)
# Out:
# 3    0.439713
# 4    0.200773
# 1    0.159086
# 2    0.101042
# 5    0.099386
# Name: ethnicity, dtype: float64

# %%
df['income'].value_counts(normalize=True)
# Out:
# 6     0.129616
# 15    0.116640
# 7     0.094140
# 5     0.083581
# 3     0.081027
# 8     0.075299
# 14    0.071295
# 4     0.069777
# 9     0.054869
# 2     0.047622
# 10    0.045897
# 11    0.029816
# 1     0.029402
# 12    0.024501
# 77    0.020498
# 99    0.014632
# 13    0.011388
# Name: income, dtype: float64

# %%
df['income'].mode()[0]
# Out:
# 6

# %%
df['income'].replace({13: 4, 12: 6, 77: 6, 99: 6}, inplace=True)
df['income'].value_counts(normalize=True)
# Out:
# 6     0.189247
# 15    0.116640
# 7     0.094140
# 5     0.083581
# 4     0.081165
# 3     0.081027
# 8     0.075299
# 14    0.071295
# 9     0.054869
# 2     0.047622
# 10    0.045897
# 11    0.029816
# 1     0.029402
# Name: income, dtype: float64

# %%
df['pulse_regular'].value_counts(normalize=True)
# Out:
# 1    0.971634
# 2    0.028366
# Name: pulse_regular, dtype: float64

# %%
df['diabetes'].value_counts(normalize=True)
# Out:
# 2    0.855477
# 1    0.122714
# 3    0.021188
# 9    0.000621
# Name: diabetes, dtype: float64

# %%
df['diabetes'].replace({3: 1, 7: 2, 9: 2}, inplace=True)

# %%
df['diabetes'].value_counts(normalize=True)
# Out:
# 2    0.856098
# 1    0.143902
# Name: diabetes, dtype: float64

# %%
df['kidney_fail'].value_counts(normalize=True)
# Out:
# 2    0.966388
# 1    0.032024
# 9    0.001587
# Name: kidney_fail, dtype: float64

# %%
df['kidney_fail'].replace({9: 2}, inplace=True)
df['kidney_fail'].value_counts(normalize=True)
# Out:
# 2    0.967976
# 1    0.032024
# Name: kidney_fail, dtype: float64

# %%
df['congestive_fail'].value_counts(normalize=True)
# Out:
# 2    0.963766
# 1    0.033819
# 9    0.002416
# Name: congestive_fail, dtype: float64

# %%
df['congestive_fail'].replace({9: 2}, inplace=True)
df['congestive_fail'].value_counts(normalize=True)
# Out:
# 2    0.966181
# 1    0.033819
# Name: congestive_fail, dtype: float64

# %%
df['coronary_disease'].value_counts(normalize=True)
# Out:
# 2    0.954931
# 1    0.040790
# 9    0.004210
# 7    0.000069
# Name: coronary_disease, dtype: float64

# %%
df['coronary_disease'].replace({9: 2, 7: 2}, inplace=True)
df['coronary_disease'].value_counts(normalize=True)
# Out:
# 2    0.95921
# 1    0.04079
# Name: coronary_disease, dtype: float64

# %%
df['angina'].value_counts(normalize=True)
# Out:
# 2    0.971358
# 1    0.025606
# 9    0.003037
# Name: angina, dtype: float64

# %%
df['angina'].replace({9: 2}, inplace=True)
df['angina'].value_counts(normalize=True)
# Out:
# 2    0.974394
# 1    0.025606
# Name: angina, dtype: float64

# %%
df['heart_attack'].value_counts(normalize=True)
# Out:
# 2    0.954793
# 1    0.043826
# 9    0.001380
# Name: heart_attack, dtype: float64

# %%
df['heart_attack'].replace({9: 2}, inplace=True)
df['heart_attack'].value_counts(normalize=True)
# Out:
# 2    0.956174
# 1    0.043826
# Name: heart_attack, dtype: float64

# %%
df['stroke'].value_counts(normalize=True)
# Out:
# 2    0.960798
# 1    0.038167
# 9    0.001035
# Name: stroke, dtype: float64

# %%
df['stroke'].replace({9: 2}, inplace=True)
df['stroke'].value_counts(normalize=True)
# Out:
# 2    0.961833
# 1    0.038167
# Name: stroke, dtype: float64

# %%
df['fam_history'].value_counts(normalize=True)
# Out:
# 2    0.851543
# 1    0.122507
# 9    0.025813
# 7    0.000138
# Name: fam_history, dtype: float64

# %%
df['fam_history'].replace({9: 2, 7: 2}, inplace=True)
df['fam_history'].value_counts(normalize=True)
# Out:
# 2    0.877493
# 1    0.122507
# Name: fam_history, dtype: float64

# %%
df['smoking'].value_counts(normalize=True)
# Out:
# 2    0.548899
# 1    0.450066
# 9    0.000897
# 7    0.000138
# Name: smoking, dtype: float64

# %%
df['smoking'].replace({9: 2, 7: 2}, inplace=True)
df['smoking'].value_counts(normalize=True)
# Out:
# 2    0.549934
# 1    0.450066
# Name: smoking, dtype: float64

# %%
df.hist(figsize=(15, 10))
plt.subplots_adjust(hspace=0.5)
plt.show()

# %%
def CVD(heart_1, heart_2, heart_3, heart_4, heart_5):
    if ((heart_1 == 1.0) or (heart_2 == 1.0) or (heart_3 == 1.0)
       or (heart_4 == 1.0) or (heart_5 == 1.0)):
        return 1
    else:
        return 0

# %%
df['CVD_risk'] = df.apply(lambda x: CVD(x['congestive_fail'], x['coronary_disease'],
                                         x['angina'], x['heart_attack'], 
                                         x['stroke']), axis=1)
df = df.drop(['congestive_fail', 'coronary_disease', 'angina', 'heart_attack', 'stroke'], 1)

# %%
df.head()
# Out:
#        gender  age  ethnicity  income  pulse_regular  sysbp  diabp    bmi  \
# seqn
# 31131       2   44          4      11              1    144     74  30.90
# 31132       1   70          3      11              1    138     60  24.74
# 31134       1   73          3       6              1    130     68  30.63
# 31150       1   79          3       3              1    144     74  28.93
# 31151       2   59          4       7              1    136     76  29.51
#
#        waistcircum  hdl  trigly  ldl  totchol  diabetes  kidney_fail  \
# seqn
# 31131         96.0   39      86   49      105         2            2
# 31132         96.5   59      65   75      147         1            2
# 31134        117.1   49     195   98      186         2            2
# 31150        107.7   81      50   90      181         2            2
# 31151        101.2   76     123  104      205         1            1
#
#        fam_history  smoking  CVD_risk
# seqn
# 31131            1        2         1
# 31132            2        2         0
# 31134            2        2         0
# 31150            2        1         0
# 31151            1        1         1

# %%
df['CVD_risk'].value_counts(normalize=True)
# Out:
# 0    0.888812
# 1    0.111188
# Name: CVD_risk, dtype: float64

# %%
sns.countplot(x='CVD_risk', data=df)
plt.xticks([0,1], ['No', 'Yes'])
plt.show()

# %%
df_grouped=df.groupby('CVD_risk')[['age', 'sysbp', 'diabp', 'bmi', 'waistcircum',
                                   'hdl', 'trigly', 'ldl', 'totchol']].mean().reset_index()
df_grouped
# Out:
#    CVD_risk        age       sysbp      diabp        bmi  waistcircum  \
# 0         0  47.575478  122.888647  69.454108  28.814981    98.186663
# 1         1  66.504655  131.234016  66.610801  30.311955   105.210551
#
#          hdl      trigly         ldl     totchol
# 0  55.004581  118.645442  115.465057  194.199177
# 1  51.547486  131.177529  100.983240  178.771570

# %%
def barplots(columns, ncol=None, figsize=(15, 8)):
    if ncol is None:
        ncol = len(columns)
    nrow = int(np.ceil(len(columns) / ncol))
    fig, axes = plt.subplots(nrow, ncol, figsize=figsize, squeeze=False)
    fig.subplots_adjust(wspace=0.3, hspace=0.6)
    for i, col in enumerate(columns):
        ax = axes.flatten()[i]
        barlist=ax.bar(x = 'CVD_risk', height = col, data=df_grouped)
        barlist[1].set_color('sandybrown')
        ax.set_xticks([0, 1])
        ax.set_xticklabels(['No', 'Yes'])
        ax.set(xlabel='CVD risk', ylabel=col)
    nsubplots = nrow * ncol    
    for empty in range(i+1, nsubplots):
        axes.flatten()[empty].set_visible(False)

# %%
features = [i for i in df_grouped.columns if i not in ['CVD_risk']]

# %%
barplots(features, ncol=4, figsize=(15, 12))

# %%
def boxplots(columns, ncol=None, figsize=(15, 8)):
    if ncol is None:
        ncol = len(columns)
    nrow = int(np.ceil(len(columns) / ncol))
    fig, axes = plt.subplots(nrow, ncol, figsize=figsize, squeeze=False)
    fig.subplots_adjust(wspace=0.3, hspace=0.6)
    for i, col in enumerate(columns):
        ax = axes.flatten()[i]
        barlist=ax.boxplot(x=col, data=df)
        ax.set(xlabel=col)
    nsubplots = nrow * ncol    
    for empty in range(i+1, nsubplots):
        axes.flatten()[empty].set_visible(False)

# %%
features = [i for i in df.columns if i in ['age', 'sysbp', 'diabp', 'bmi', 'waistcircum',
                                   'hdl', 'trigly', 'ldl', 'totchol']]

# %%
boxplots(features, ncol=4, figsize=(15, 12))

# %%
plt.figure(figsize=(15, 8))
sns.boxplot(data=df[['age', 'sysbp', 'diabp', 'bmi', 'waistcircum',
                                   'hdl', 'trigly', 'ldl', 'totchol']])
plt.show()

# %%
df['gender_cat']=df['gender'].replace({1.0: 'Male', 2.0: 'Female'})

# %%
ax=sns.countplot(x='gender_cat', hue='CVD_risk', data=df)
ax.set_title('Gender Distribution')
ax.set_xlabel("Gender")
ax.set_ylabel("Count")
labels = ['No', 'Yes']
plt.legend(labels = labels, title = 'CVD risk')
plt.show()

# %%
def relative_risk(df, col, *categories):
    risk_ratio=[]
    for i in range(len(categories)):
        risk = len(df[(df['CVD_risk'] == 1) & (df[col] == categories[i])])/len(df[df[col] == categories[i]])
        risk_ratio.append(risk)
    return risk_ratio

# %%
CVD_risk_gender = relative_risk(df, 'gender_cat','Male', 'Female')
print('The percentage of males with CVD_risk is {:.2%}'. format(CVD_risk_gender[0]))
print('The percentage of females with CVD_risk is {:.2%}'. format(CVD_risk_gender[1]))
# Out:
# The percentage of males with CVD_risk is 12.93%
# The percentage of females with CVD_risk is 9.45%

# %%
ax=sns.histplot(df['age'],kde = False)
ax.set_title('Age Distribution')
ax.set_xlabel("Age")
plt.show()

# %%
df['age_cat'] = pd.cut(x=df['age'], bins=[20, 29, 39, 49, 59, 69, 79],
                       labels=['20s', '30s', '40s', '50s', '60s', '70s & above'])

# %%
ax=sns.countplot(x='age_cat',data=df, hue='gender_cat')
ax.set_title('Age Category Distribution')
ax.set_xlabel('Age Category')
ax.set_ylabel('Count')
plt.show()

# %%
ax=sns.countplot(x='age_cat',data=df, hue='CVD_risk')
ax.set_title('Age Category Distribution')
ax.set_xlabel('Age Category')
ax.set_ylabel('Count')
labels = ['No', 'Yes']
plt.legend(labels = labels, title = 'CVD risk')
plt.show()

# %%
CVD_risk_age = relative_risk(df, 'age_cat','20s', '30s', '40s', '50s', '60s', '70s & above')
print('The percentage of individuals in 20s with CVD_risk is {:.2%}'. format(CVD_risk_age[0]))
print('The percentage of individuals in 30s with CVD_risk is {:.2%}'. format(CVD_risk_age[1]))
print('The percentage of individuals in 40s with CVD_risk is {:.2%}'. format(CVD_risk_age[2]))
print('The percentage of individuals in 50s with CVD_risk is {:.2%}'. format(CVD_risk_age[3]))
print('The percentage of individuals in 60s with CVD_risk is {:.2%}'. format(CVD_risk_age[4]))
print('The percentage of individuals in 70s and above with CVD_risk is {:.2%}'. format(CVD_risk_age[5]))
# Out:
# The percentage of individuals in 20s with CVD_risk is 0.73%
# The percentage of individuals in 30s with CVD_risk is 1.74%
# The percentage of individuals in 40s with CVD_risk is 5.10%
# The percentage of individuals in 50s with CVD_risk is 9.19%
# The percentage of individuals in 60s with CVD_risk is 18.49%
# The percentage of individuals in 70s and above with CVD_risk is 27.09%

# %%
df['ethnicity_cat']=df['ethnicity'].replace({1.0: 'Mexican', 2.0: 'Hispanic',
                                         3.0: 'White', 4.0: 'Black',
                                         5.0:'Other'})

# %%
ax=sns.countplot(x='ethnicity_cat',hue='CVD_risk', data=df)
ax.set_title('Ethnicity Distribution')
ax.set_xlabel('Ethnicity')
ax.set_ylabel('Count')
labels = ['No', 'Yes']
plt.legend(labels = labels, title = 'CVD risk')
plt.tight_layout()

# %%
CVD_risk_ethnicity = relative_risk(df, 'ethnicity_cat','Black', 'White', 'Mexican', 'Hispanic', 'Other')
print('The percentage of Blacks with CVD_risk is {:.2%}'. format(CVD_risk_ethnicity[0]))
print('The percentage of Whites with CVD_risk is {:.2%}'. format(CVD_risk_ethnicity[1]))
print('The percentage of Mexicans with CVD_risk is {:.2%}'. format(CVD_risk_ethnicity[2]))
print('The percentage of Hispanics with CVD_risk is {:.2%}'. format(CVD_risk_ethnicity[3]))
print('The percentage of Others with CVD_risk is {:.2%}'. format(CVD_risk_ethnicity[4]))
# Out:
# The percentage of Blacks with CVD_risk is 11.69%
# The percentage of Whites with CVD_risk is 14.03%
# The percentage of Mexicans with CVD_risk is 6.68%
# The percentage of Hispanics with CVD_risk is 9.15%
# The percentage of Others with CVD_risk is 6.18%

# %%
def income_cat(income):
    if ((income == 1) or (income == 2)
       or (income == 3) or (income == 4)
       or (income == 5)):
        return 'lowest'
    elif ((income == 6) or (income == 7)
          or (income == 8) or (income == 9)
         or (income == 10)):
        return 'lower middle'
    else:
        return 'middle & over'

# %%
df['income_cat'] = df.apply(lambda x : income_cat(x['income']), axis=1)

# %%
df['income_cat'].value_counts(normalize=True)
# Out:
# lower middle     0.459452
# lowest           0.322797
# middle & over    0.217751
# Name: income_cat, dtype: float64

# %%
ax=sns.countplot(x='income_cat',hue='CVD_risk', data=df)
ax.set_title('Income Category Distribution')
ax.set_xlabel('Family Income Category')
ax.set_ylabel('Count')
labels = ['No', 'Yes']
plt.legend(labels = labels, title = 'CVD risk')
plt.show()

# %%
CVD_risk_income = relative_risk(df, 'income_cat','lowest', 'lower middle', 'middle & over')
print('The percentage of individuals in lowest income class with CVD_risk is {:.2%}'. format(CVD_risk_income[0]))
print('The percentage of individuals in lower middle income class with CVD_risk is {:.2%}'. format(CVD_risk_income[1]))
print('The percentage of individuals in middle and over income class with CVD_risk is {:.2%}'. format(CVD_risk_income[2]))
# Out:
# The percentage of individuals in lowest income class with CVD_risk is 14.73%
# The percentage of individuals in lower middle income class with CVD_risk is 10.91%
# The percentage of individuals in middle and over income class with CVD_risk is 6.21%

# %%
plt.figure(figsize=(10,6))
sns.countplot(x='income_cat', hue='ethnicity_cat', data=df)

# %%
def pulse_cat(puls):
    if puls==2.0:
        return 1
    else:
        return 0

# %%
df['pulse_cat'] = df.apply(lambda x: pulse_cat(x['pulse_regular']), axis=1)

# %%
sns.countplot(x='pulse_cat', hue='CVD_risk', data=df)
plt.xticks([0,1], ['Regular', 'Irregular'])
labels = ['No', 'Yes']
plt.legend(labels = labels, title = 'CVD risk')

# %%
CVD_risk_pulse = relative_risk(df, 'pulse_cat', 1, 0)
print('The percentage of individuals with irregular pulse with CVD_risk is {:.2%}'. format(CVD_risk_pulse[0]))
print('The percentage of individuals with regular pulse of heart diseases with CVD_risk is {:.2%}'. format(CVD_risk_pulse[1]))
# Out:
# The percentage of individuals with irregular pulse with CVD_risk is 31.87%
# The percentage of individuals with regular pulse of heart diseases with CVD_risk is 10.51%

# %%
def hyper(sbp, dbp):
    if ((sbp <= 130) and (dbp <= 80)):    
        return 0
    else:
        return 1

# %%
df['hypertension_cat'] = df.apply(lambda x : hyper(x['sysbp'], x['diabp']), axis=1)

# %%
sns.countplot(x='hypertension_cat', hue='CVD_risk', data=df)
plt.xticks([0,1], ['Normal', 'High'])
labels = ['No', 'Yes']
plt.legend(labels = labels, title = 'CVD risk')

# %%
CVD_risk_hypertension = relative_risk(df, 'hypertension_cat', 1, 0)
print('The percentage of hypertensive individuals with CVD_risk is {:.2%}'. format(CVD_risk_hypertension[0]))
print('The percentage of non-hypertensive individuals with CVD_risk is {:.2%}'. format(CVD_risk_hypertension[1]))
# Out:
# The percentage of hypertensive individuals with CVD_risk is 15.98%
# The percentage of non-hypertensive individuals with CVD_risk is 8.75%

# %%
df['bmi_cat'] = pd.cut(x=df['bmi'], bins=[0, 18.5, 24.9, 'inf'],
                       labels=['underweight', 'ideal', 'overweight'])

# %%
sns.countplot(x='bmi_cat', hue='CVD_risk', data=df)
labels = ['No', 'Yes']
plt.legend(labels = labels, title = 'CVD risk')

# %%
CVD_risk_weight = relative_risk(df, 'bmi_cat', 'underweight', 'ideal', 'overweight')
print('The percentage of underweight individuals with CVD_risk is {:.2%}'. format(CVD_risk_weight[0]))
print('The percentage of ideal weight individuals with CVD_risk is {:.2%}'. format(CVD_risk_weight[1]))
print('The percentage of overweight individuals with CVD_risk is {:.2%}'. format(CVD_risk_weight[2]))
# Out:
# The percentage of underweight individuals with CVD_risk is 8.43%
# The percentage of ideal weight individuals with CVD_risk is 7.95%
# The percentage of overweight individuals with CVD_risk is 12.43%

# %%
def waist_cat(gender,waist):
    if ((gender == 1.0 and waist < 102) or (gender == 2.0 and waist < 89)):
        return 0
    else:
        return 1

# %%
df['waistcircum_cat'] = df.apply(lambda x : waist_cat(x['gender'], x['waistcircum']), axis=1)

# %%
sns.countplot(x='waistcircum_cat', hue='CVD_risk', data=df)
plt.xticks([0,1], ['Normal', 'High'])
labels = ['No', 'Yes']
plt.legend(labels = labels, title = 'CVD risk')

# %%
CVD_risk_waist = relative_risk(df, 'waistcircum_cat', 1, 0)
print('The percentage of high waist circumference individuals with CVD_risk is {:.2%}'. format(CVD_risk_waist[0]))
print('The percentage of ideal waist circumference individuals with CVD_risk is {:.2%}'. format(CVD_risk_waist[1]))
# Out:
# The percentage of high waist circumference individuals with CVD_risk is 13.62%
# The percentage of ideal waist circumference individuals with CVD_risk is 8.03%

# %%
sns.regplot(x='bmi', y='waistcircum', data=df)

# %%
def hdl_cat(hdl):
    if hdl > 60:
        return 0
    else:
        return 1

# %%
df['hdl_cat'] = df.apply(lambda x : hdl_cat(x['hdl']), axis=1)

# %%
sns.countplot(x='hdl_cat', hue='CVD_risk', data=df)
plt.xticks([0,1], ['Normal', 'Low'])
labels = ['No', 'Yes']
plt.legend(labels = labels, title = 'CVD risk')

# %%
CVD_risk_hdl = relative_risk(df, 'hdl_cat', 0, 1)
print('The percentage of normal HDL levels individuals with CVD_risk is {:.2%}'. format(CVD_risk_hdl[0]))
print('The percentage of low HDL levels individuals with CVD_risk is {:.2%}'. format(CVD_risk_hdl[1]))
# Out:
# The percentage of normal HDL levels individuals with CVD_risk is 8.83%
# The percentage of low HDL levels individuals with CVD_risk is 12.12%

# %%
sns.regplot(x='hdl', y='waistcircum', data=df)

# %%
def trigly_cat(trigly):
    if trigly < 130:
        return 0
    else:
        return 1

# %%
df['trigly_cat'] = df.apply(lambda x : trigly_cat(x['trigly']), axis=1)

# %%
sns.countplot(x='trigly_cat', hue='CVD_risk', data=df)
plt.xticks([0,1], ['Normal', 'High'])
labels = ['No', 'Yes']
plt.legend(labels = labels, title = 'CVD risk')

# %%
CVD_risk_trigly = relative_risk(df, 'trigly_cat', 0, 1)
print('The percentage of normal triglyceride levels individuals with CVD_risk is {:.2%}'. format(CVD_risk_trigly[0]))
print('The percentage of high triglyceride levels individuals with CVD_risk is {:.2%}'. format(CVD_risk_trigly[1]))
# Out:
# The percentage of normal triglyceride levels individuals with CVD_risk is 9.94%
# The percentage of high triglyceride levels individuals with CVD_risk is 13.41%

# %%
sns.regplot(x='hdl', y='trigly', data=df)

# %%
def ldl_cat(ldl):
    if ldl < 100:
        return 0
    else:
        return 1

# %%
df['ldl_cat'] = df.apply(lambda x : ldl_cat(x['ldl']), axis=1)

# %%
sns.countplot(x='ldl_cat', hue='CVD_risk', data=df)
plt.xticks([0,1], ['Normal', 'High'])
labels = ['No', 'Yes']
plt.legend(labels = labels, title = 'CVD risk')

# %%
CVD_risk_ldl = relative_risk(df, 'ldl_cat', 0, 1)
print('The percentage of normal ldl levels individuals with CVD_risk is {:.2%}'. format(CVD_risk_ldl[0]))
print('The percentage of high ldl levels individuals with CVD_risk is {:.2%}'. format(CVD_risk_ldl[1]))
# Out:
# The percentage of normal ldl levels individuals with CVD_risk is 16.86%
# The percentage of high ldl levels individuals with CVD_risk is 7.79%

# %%
def totalchol_cat(chol):
    if chol < 200:
        return 0
    else:
        return 1

# %%
df['totchol_cat'] = df.apply(lambda x : totalchol_cat(x['totchol']), axis=1)

# %%
sns.countplot(x='totchol_cat', hue='CVD_risk', data=df)
plt.xticks([0,1], ['Normal', 'High'])
labels = ['No', 'Yes']
plt.legend(labels = labels, title = 'CVD risk')

# %%
CVD_risk_chol = relative_risk(df, 'totchol_cat', 0, 1)
print('The percentage of normal total cholestrol levels individuals with CVD_risk is {:.2%}'. format(CVD_risk_chol[0]))
print('The percentage of high total cholestrol levels individuals with CVD_risk is {:.2%}'. format(CVD_risk_chol[1]))
# Out:
# The percentage of normal total cholestrol levels individuals with CVD_risk is 13.46%
# The percentage of high total cholestrol levels individuals with CVD_risk is 7.65%

# %%
def diab_cat(diab):
    if diab==1.0:
        return 1
    else:
        return 0

# %%
df['diabetes_cat'] = df.apply(lambda x: diab_cat(x['diabetes']), axis=1)

# %%
sns.countplot(x='diabetes_cat', hue='CVD_risk', data=df)
plt.xticks([0,1], ['Non-diabetic', 'Diabetic'])
labels = ['No', 'Yes']
plt.legend(labels = labels, title = 'CVD risk')

# %%
CVD_risk_diabetes = relative_risk(df, 'diabetes_cat', 0, 1)
print('The percentage of non-diabetic individuals with CVD_risk is {:.2%}'. format(CVD_risk_diabetes[0]))
print('The percentage of diabetic individuals with CVD_risk is {:.2%}'. format(CVD_risk_diabetes[1]))
# Out:
# The percentage of non-diabetic individuals with CVD_risk is 8.29%
# The percentage of diabetic individuals with CVD_risk is 27.96%

# %%
def kidn_cat(kidn):
    if kidn==1.0:
        return 1
    else:
        return 0

# %%
df['kidney_cat'] = df.apply(lambda x: kidn_cat(x['kidney_fail']), axis=1)

# %%
sns.countplot(x='kidney_cat', hue='CVD_risk', data=df)
plt.xticks([0,1], ['No kidney failure', 'Kidney failure'])
labels = ['No', 'Yes']
plt.legend(labels = labels, title = 'CVD risk')

# %%
CVD_risk_kidney = relative_risk(df, 'kidney_cat', 0, 1)
print('The percentage of normal kidney function individuals with CVD_risk is {:.2%}'. format(CVD_risk_kidney[0]))
print('The percentage of kidney failure individuals with CVD_risk is {:.2%}'. format(CVD_risk_kidney[1]))
# Out:
# The percentage of normal kidney function individuals with CVD_risk is 10.24%
# The percentage of kidney failure individuals with CVD_risk is 37.72%

# %%
def famhis_cat(fam):
    if fam == 1.0:
        return 1
    else:
        return 0

# %%
df['family_history_cat'] = df.apply(lambda x: famhis_cat(x['fam_history']), axis=1)

# %%
sns.countplot(x='family_history_cat', hue='CVD_risk', data=df)
plt.xticks([0,1], ['No family history', 'Family history'])
labels = ['No', 'Yes']
plt.legend(labels = labels, title = 'CVD risk')

# %%
CVD_risk_famhistory = relative_risk(df, 'family_history_cat', 0, 1)
print('The percentage of individuals with no family history of heart diseases with CVD_risk is {:.2%}'. format(CVD_risk_famhistory[0]))
print('The percentage of individuals with family history of heart diseases with CVD_risk is {:.2%}'. format(CVD_risk_famhistory[1]))
# Out:
# The percentage of individuals with no family history of heart diseases with CVD_risk is 9.86%
# The percentage of individuals with family history of heart diseases with CVD_risk is 20.17%

# %%
def smoking_cat(smoker):
    if smoker == 1:
        return 1
    else:
        return 0

# %%
df['smoking_cat'] = df.apply(lambda x : smoking_cat(x['smoking']), axis=1)

# %%
sns.countplot(x='smoking_cat', hue='CVD_risk', data=df)
plt.xticks([0,1], ['Non-smoker', 'Smoker'])
labels = ['No', 'Yes']
plt.legend(labels = labels, title = 'CVD risk')

# %%
CVD_risk_smoking = relative_risk(df, 'smoking_cat', 0, 1)
print('The percentage of non-smoking individuals with CVD_risk is {:.2%}'. format(CVD_risk_smoking[0]))
print('The percentage of smoking individuals with CVD_risk is {:.2%}'. format(CVD_risk_smoking[1]))
# Out:
# The percentage of non-smoking individuals with CVD_risk is 8.25%
# The percentage of smoking individuals with CVD_risk is 14.63%

# %%
df.columns
# Out:
# Index(['gender', 'age', 'ethnicity', 'income', 'pulse_regular', 'sysbp',
#        'diabp', 'bmi', 'waistcircum', 'hdl', 'trigly', 'ldl', 'totchol',
#        'diabetes', 'kidney_fail', 'fam_history', 'smoking', 'CVD_risk',
#        'gender_cat', 'age_cat', 'ethnicity_cat', 'income_cat', 'pulse_cat',
#        'hypertension_cat', 'bmi_cat', 'waistcircum_cat', 'hdl_cat',
#        'trigly_cat', 'ldl_cat', 'totchol_cat', 'diabetes_cat', 'kidney_cat',
#        'family_history_cat', 'smoking_cat'],
#       dtype='object')

# %%
df.head().T
# Out:
# seqn                        31131          31132         31134        31150  \
# gender                          2              1             1            1
# age                            44             70            73           79
# ethnicity                       4              3             3            3
# income                         11             11             6            3
# pulse_regular                   1              1             1            1
# sysbp                         144            138           130          144
# diabp                          74             60            68           74
# bmi                          30.9          24.74         30.63        28.93
# waistcircum                    96           96.5         117.1        107.7
# hdl                            39             59            49           81
# trigly                         86             65           195           50
# ldl                            49             75            98           90
# totchol                       105            147           186          181
# diabetes                        2              1             2            2
# kidney_fail                     2              2             2            2
# fam_history                     1              2             2            2
# smoking                         2              2             2            1
# CVD_risk                        1              0             0            0
# gender_cat                 Female           Male          Male         Male
# age_cat                       40s    70s & above   70s & above  70s & above
# ethnicity_cat               Black          White         White        White
# income_cat          middle & over  middle & over  lower middle       lowest
# pulse_cat                       0              0             0            0
# hypertension_cat                1              1             0            1
# bmi_cat                overweight          ideal    overweight   overweight
# waistcircum_cat                 1              0             1            1
# hdl_cat                         1              1             1            0
# trigly_cat                      0              0             1            0
# ldl_cat                         0              0             0            0
# totchol_cat                     0              0             0            0
# diabetes_cat                    0              1             0            0
# kidney_cat                      0              0             0            0
# family_history_cat              1              0             0            0
# smoking_cat                     0              0             0            1
#
# seqn                       31151
# gender                         2
# age                           59
# ethnicity                      4
# income                         7
# pulse_regular                  1
# sysbp                        136
# diabp                         76
# bmi                        29.51
# waistcircum                101.2
# hdl                           76
# trigly                       123
# ldl                          104
# totchol                      205
# diabetes                       1
# kidney_fail                    1
# fam_history                    1
# smoking                        1
# CVD_risk                       1
# gender_cat                Female
# age_cat                      50s
# ethnicity_cat              Black
# income_cat          lower middle
# pulse_cat                      0
# hypertension_cat               1
# bmi_cat               overweight
# waistcircum_cat                1
# hdl_cat                        0
# trigly_cat                     0
# ldl_cat                        1
# totchol_cat                    1
# diabetes_cat                   1
# kidney_cat                     1
# family_history_cat             1
# smoking_cat                    1

# %%
sns.pairplot(df, hue='CVD_risk', vars=['age', 'sysbp', 'diabp', 'bmi', 'waistcircum',
                                       'hdl', 'trigly', 'ldl', 'totchol'])

# %%
# Adding heatmaps
corr = df[['gender', 'age', 'bmi', 'pulse_cat', 'hypertension_cat',
           'waistcircum_cat', 'totchol_cat', 'hdl_cat', 'ldl_cat', 'trigly_cat',
           'diabetes_cat', 'kidney_cat', 'family_history_cat', 'smoking_cat', 'CVD_risk']].corr()
plt.figure(figsize=(24,12))
heatmap = sns.heatmap(corr, vmin=-1, vmax=1, cmap='BrBG')
heatmap.set_title('Correlation Heatmap', fontdict={'fontsize':20}, pad=12);

# %%
df_dummies=pd.get_dummies(df)

# %%
df_dummies.head().T
# Out:
# seqn                      31131   31132   31134   31150   31151
# gender                      2.0    1.00    1.00    1.00    2.00
# age                        44.0   70.00   73.00   79.00   59.00
# ethnicity                   4.0    3.00    3.00    3.00    4.00
# income                     11.0   11.00    6.00    3.00    7.00
# pulse_regular               1.0    1.00    1.00    1.00    1.00
# sysbp                     144.0  138.00  130.00  144.00  136.00
# diabp                      74.0   60.00   68.00   74.00   76.00
# bmi                        30.9   24.74   30.63   28.93   29.51
# waistcircum                96.0   96.50  117.10  107.70  101.20
# hdl                        39.0   59.00   49.00   81.00   76.00
# trigly                     86.0   65.00  195.00   50.00  123.00
# ldl                        49.0   75.00   98.00   90.00  104.00
# totchol                   105.0  147.00  186.00  181.00  205.00
# diabetes                    2.0    1.00    2.00    2.00    1.00
# kidney_fail                 2.0    2.00    2.00    2.00    1.00
# fam_history                 1.0    2.00    2.00    2.00    1.00
# smoking                     2.0    2.00    2.00    1.00    1.00
# CVD_risk                    1.0    0.00    0.00    0.00    1.00
# pulse_cat                   0.0    0.00    0.00    0.00    0.00
# hypertension_cat            1.0    1.00    0.00    1.00    1.00
# waistcircum_cat             1.0    0.00    1.00    1.00    1.00
# hdl_cat                     1.0    1.00    1.00    0.00    0.00
# trigly_cat                  0.0    0.00    1.00    0.00    0.00
# ldl_cat                     0.0    0.00    0.00    0.00    1.00
# totchol_cat                 0.0    0.00    0.00    0.00    1.00
# diabetes_cat                0.0    1.00    0.00    0.00    1.00
# kidney_cat                  0.0    0.00    0.00    0.00    1.00
# family_history_cat          1.0    0.00    0.00    0.00    1.00
# smoking_cat                 0.0    0.00    0.00    1.00    1.00
# gender_cat_Female           1.0    0.00    0.00    0.00    1.00
# gender_cat_Male             0.0    1.00    1.00    1.00    0.00
# age_cat_20s                 0.0    0.00    0.00    0.00    0.00
# age_cat_30s                 0.0    0.00    0.00    0.00    0.00
# age_cat_40s                 1.0    0.00    0.00    0.00    0.00
# age_cat_50s                 0.0    0.00    0.00    0.00    1.00
# age_cat_60s                 0.0    0.00    0.00    0.00    0.00
# age_cat_70s & above         0.0    1.00    1.00    1.00    0.00
# ethnicity_cat_Black         1.0    0.00    0.00    0.00    1.00
# ethnicity_cat_Hispanic      0.0    0.00    0.00    0.00    0.00
# ethnicity_cat_Mexican       0.0    0.00    0.00    0.00    0.00
# ethnicity_cat_Other         0.0    0.00    0.00    0.00    0.00
# ethnicity_cat_White         0.0    1.00    1.00    1.00    0.00
# income_cat_lower middle     0.0    0.00    1.00    0.00    1.00
# income_cat_lowest           0.0    0.00    0.00    1.00    0.00
# income_cat_middle & over    1.0    1.00    0.00    0.00    0.00
# bmi_cat_underweight         0.0    0.00    0.00    0.00    0.00
# bmi_cat_ideal               0.0    1.00    0.00    0.00    0.00
# bmi_cat_overweight          1.0    0.00    1.00    1.00    1.00

# %%
df_dummies.columns
# Out:
# Index(['gender', 'age', 'ethnicity', 'income', 'pulse_regular', 'sysbp',
#        'diabp', 'bmi', 'waistcircum', 'hdl', 'trigly', 'ldl', 'totchol',
#        'diabetes', 'kidney_fail', 'fam_history', 'smoking', 'CVD_risk',
#        'pulse_cat', 'hypertension_cat', 'waistcircum_cat', 'hdl_cat',
#        'trigly_cat', 'ldl_cat', 'totchol_cat', 'diabetes_cat', 'kidney_cat',
#        'family_history_cat', 'smoking_cat', 'gender_cat_Female',
#        'gender_cat_Male', 'age_cat_20s', 'age_cat_30s', 'age_cat_40s',
#        'age_cat_50s', 'age_cat_60s', 'age_cat_70s & above',
#        'ethnicity_cat_Black', 'ethnicity_cat_Hispanic',
#        'ethnicity_cat_Mexican', 'ethnicity_cat_Other', 'ethnicity_cat_White',
#        'income_cat_lower middle', 'income_cat_lowest',
#        'income_cat_middle & over', 'bmi_cat_underweight', 'bmi_cat_ideal',
#        'bmi_cat_overweight'],
#       dtype='object')

# %%
variables=['gender_cat_Female', 'gender_cat_Male', 'age_cat_20s',
           'age_cat_30s', 'age_cat_40s', 'age_cat_50s', 'age_cat_60s',
           'age_cat_70s & above', 'ethnicity_cat_Black', 'ethnicity_cat_Hispanic',
           'ethnicity_cat_Mexican', 'ethnicity_cat_Other', 'ethnicity_cat_White',
           'income_cat_lower middle', 'income_cat_lowest', 'income_cat_middle & over',
           'bmi_cat_underweight', 'bmi_cat_ideal', 'bmi_cat_overweight']
d = {'Variable':[],'Odds Ratio':[],'LCB':[],'UCB':[]}
for variable in variables:
    CTab=pd.crosstab(df_dummies[variable],df_dummies['CVD_risk'])
    Odds = sm.stats.Table2x2(CTab)
    d['Variable'].append(variable)
    d['Odds Ratio'].append(Odds.oddsratio)
    lcb,ucb = Odds.oddsratio_confint()
    d['LCB'].append(lcb)
    d['UCB'].append(ucb)

results = pd.DataFrame(d)
results.sort_values(by='Odds Ratio', ascending=False, inplace=True)
results.reset_index()
# Out:
#     index                  Variable  Odds Ratio       LCB       UCB
# 0       7       age_cat_70s & above    3.668549  3.232116  4.163914
# 1       6               age_cat_60s    2.116657  1.877244  2.386603
# 2      12       ethnicity_cat_White    1.684869  1.518016  1.870061
# 3      14         income_cat_lowest    1.665846  1.499003  1.851260
# 4      18        bmi_cat_overweight    1.637643  1.444615  1.856464
# 5       1           gender_cat_Male    1.423234  1.282348  1.579599
# 6       8       ethnicity_cat_Black    1.073460  0.945210  1.219111
# 7      13   income_cat_lower middle    0.960866  0.865888  1.066262
# 8       9    ethnicity_cat_Hispanic    0.787734  0.654222  0.948492
# 9       5               age_cat_50s    0.780172  0.670061  0.908378
# 10     16       bmi_cat_underweight    0.732173  0.471650  1.136600
# 11      0         gender_cat_Female    0.702625  0.633072  0.779820
# 12     17             bmi_cat_ideal    0.613781  0.539769  0.697942
# 13     10     ethnicity_cat_Mexican    0.527107  0.443632  0.626290
# 14     11       ethnicity_cat_Other    0.498926  0.399977  0.622353
# 15     15  income_cat_middle & over    0.464326  0.397688  0.542129
# 16      4               age_cat_40s    0.380816  0.315985  0.458948
# 17      3               age_cat_30s    0.118318  0.086809  0.161265
# 18      2               age_cat_20s    0.049173  0.029987  0.080635

# %%
plt.figure(figsize=(20,6))
plt.bar(x='Variable',height='Odds Ratio', data=results.head(12))
plt.tight_layout()
plt.show()
